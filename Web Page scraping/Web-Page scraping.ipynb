# %%
import requests

# %%
import pandas as pd

# %%
import os

# %%
from bs4 import BeautifulSoup

# %%
url = 'https://quotes.toscrape.com/'

# %%
page = requests.get(url)

# %%
fd = os.open('main2.html', os.O_WRONLY | os.O_CREAT)
os.write(fd, page.text.encode())
os.close(fd)#thats runs

# %%
Soup = BeautifulSoup(page.text,"html.parser")

# %%
print(Soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Quotes to Scrape
#   </title>
#   <link href="/static/bootstrap.min.css" rel="stylesheet"/>
#   <link href="/static/main.css" rel="stylesheet"/>
#  </head>
#  <body>
#   <div class="container">
#    <div class="row header-box">
#     <div class="col-md-8">
#      <h1>
#       <a href="/" style="text-decoration: none">
#        Quotes to Scrape
#       </a>
#      </h1>
#     </div>
#     <div class="col-md-4">
#      <p>
#       <a href="/login">
#        Login
#       </a>
#      </p>
#     </div>
#    </div>
#    <div class="row">
#     <div class="col-md-8">
#      <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#       <span class="text" itemprop="text">
#        “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
#       </span>
#       <span>
#        by
# ...

# %%
#only extract one quote
print(Soup.find('span', class_ = 'text').text[1:-1])
# Out:
# The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.

# %%
#find_all extract all quotes which have under class (span)
Soup.find_all('span', class_ = 'text')
# Out:
# [<span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>,
#  <span class="text" itemprop="text">“It is our choices, Harry, that show what we truly are, far more than our abilities.”</span>,
#  <span class="text" itemprop="text">“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”</span>,
#  <span class="text" itemprop="text">“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”</span>,
#  <span class="text" itemprop="text">“Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”</span>,
#  <span class="text" itemprop="text">“Try not to become a man of success. Rather become a man of value.”</span>,
# ...

# %%
len(Soup.find_all('span', class_ = 'text'))
# Out:
# 10

# %%
for quotes in Soup.find_all('span', class_ = 'text'):
    print(quotes.text)#print all quotes in text
    print() #this create a space between each quote
# Out:
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
#
# “It is our choices, Harry, that show what we truly are, far more than our abilities.”
#
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
#
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
#
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
#
# “Try not to become a man of success. Rather become a man of value.”
#
# “It is better to be hated for what you are than to be loved for what you are not.”
#
# “I have not failed. I've just found 10,000 ways that won't work.”
#
# “A woman is like a tea bag; you never know how strong it is until it's in hot water.”
#
# “A day without sunshine is like, you know, night.”

# %%
for quotes in Soup.find_all('span', class_ = 'text'):
    print(quotes.text[1:-1])#this will remove comos from starting and end
    print()
# Out:
# The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.
#
# It is our choices, Harry, that show what we truly are, far more than our abilities.
#
# There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.
#
# The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.
#
# Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.
#
# Try not to become a man of success. Rather become a man of value.
#
# It is better to be hated for what you are than to be loved for what you are not.
#
# I have not failed. I've just found 10,000 ways that won't work.
#
# A woman is like a tea bag; you never know how strong it is until it's in hot water.
#
# A day without sunshine is like, you know, night.

# %%
quotes = []

for quote in Soup.find_all('span', class_ = 'text'):
    quotes.append(quote.text[1:-1])

# %%
quotes
# Out:
# ['The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.',
#  'It is our choices, Harry, that show what we truly are, far more than our abilities.',
#  'There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.',
#  'The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.',
#  "Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.",
#  'Try not to become a man of success. Rather become a man of value.',
#  'It is better to be hated for what you are than to be loved for what you are not.',
#  "I have not failed. I've just found 10,000 ways that won't work.",
#  "A woman is like a tea bag; you never know how strong it is until it's in hot water.",
#  'A day without sunshine is like, you know, night.']

# %%
Soup.title
# Out:
# <title>Quotes to Scrape</title>

# %%
Soup.p #to check the name of paragraph
# Out:
# <p>
# <a href="/login">Login</a>
# </p>

# %%
Soup.h1 #to check header tag
# Out:
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>

# %%
#tag
tag = Soup.html

# %%
type(tag)
# Out:
# bs4.element.Tag

# %%
Soup.head
# Out:
# <head>
# <meta charset="utf-8"/>
# <title>Quotes to Scrape</title>
# <link href="/static/bootstrap.min.css" rel="stylesheet"/>
# <link href="/static/main.css" rel="stylesheet"/>
# </head>

# %% [markdown]
# # Quotes with Author details

# %%
#this will extract all tags from div under quote
Soup.find_all('div',class_ = 'quote')
# Out:
# [<div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
#  <span>by <small class="author" itemprop="author">Albert Einstein</small>
#  <a href="/author/Albert-Einstein">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
#  <a class="tag" href="/tag/change/page/1/">change</a>
#  <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
#  <a class="tag" href="/tag/thinking/page/1/">thinking</a>
#  <a class="tag" href="/tag/world/page/1/">world</a>
#  </div>
#  </div>,
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“It is our choices, Harry, that show what we truly are, far more than our abilities.”</span>
# ...

# %%
len(Soup.find_all('div',class_ = 'quote'))
# Out:
# 10

# %%
#for first tag
Soup.find_all('div',class_ = 'quote')[0]
# Out:
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
# <a class="tag" href="/tag/change/page/1/">change</a>
# <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
# <a class="tag" href="/tag/thinking/page/1/">thinking</a>
# <a class="tag" href="/tag/world/page/1/">world</a>
# </div>
# </div>

# %%
for sp in Soup.find_all('div',class_ = 'quote'):
    print(sp) 
    print()
# Out:
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
# <a class="tag" href="/tag/change/page/1/">change</a>
# <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
# <a class="tag" href="/tag/thinking/page/1/">thinking</a>
# <a class="tag" href="/tag/world/page/1/">world</a>
# </div>
# </div>
#
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“It is our choices, Harry, that show what we truly are, far more than our abilities.”</span>
# ...

# %%
sp
# Out:
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“A day without sunshine is like, you know, night.”</span>
# <span>by <small class="author" itemprop="author">Steve Martin</small>
# <a href="/author/Steve-Martin">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="humor,obvious,simile" itemprop="keywords"/>
# <a class="tag" href="/tag/humor/page/1/">humor</a>
# <a class="tag" href="/tag/obvious/page/1/">obvious</a>
# <a class="tag" href="/tag/simile/page/1/">simile</a>
# </div>
# </div>

# %%
quote = sp.find('span',class_ = 'text').text[1:-1]

# %%
quote
# Out:
# 'A day without sunshine is like, you know, night.'

# %%
for sp in Soup.find_all('div',class_ = 'quote'):
    quote = sp.find('span',class_ = 'text').text[1:-1]
    #from above line we can print all quotes which class as text in span
    print(quote)
# Out:
# The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.
# It is our choices, Harry, that show what we truly are, far more than our abilities.
# There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.
# The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.
# Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.
# Try not to become a man of success. Rather become a man of value.
# It is better to be hated for what you are than to be loved for what you are not.
# I have not failed. I've just found 10,000 ways that won't work.
# A woman is like a tea bag; you never know how strong it is until it's in hot water.
# A day without sunshine is like, you know, night.

# %%
sp.find('small').text
# Out:
# 'Steve Martin'

# %%
sp.find("small", class_ = 'author').text
# Out:
# 'Steve Martin'

# %%
author = sp.find('small').text

# %%
for sp in Soup.find_all('div',class_ = 'quote'):
    quote = sp.find('span',class_ = 'text').text[1:-1]
    author = sp.find('small').text
    print(author)
# Out:
# Albert Einstein
# J.K. Rowling
# Albert Einstein
# Jane Austen
# Marilyn Monroe
# Albert Einstein
# André Gide
# Thomas A. Edison
# Eleanor Roosevelt
# Steve Martin

# %%
sp.find('a')#give about imformation of author
# Out:
# <a href="/author/Steve-Martin">(about)</a>

# %%
sp.find('a').text
# Out:
# '(about)'

# %%
sp.find('a').get('href')
# Out:
# '/author/Steve-Martin'

# %%
author_id = sp.find('a').get('href')

# %%
for sp in Soup.find_all('div',class_ = 'quote'):
    quote = sp.find('span',class_ = 'text').text[1:-1]
    author = sp.find('small').text
    author_id = sp.find('a').get('href')
    print(author_id)
# Out:
# /author/Albert-Einstein
# /author/J-K-Rowling
# /author/Albert-Einstein
# /author/Jane-Austen
# /author/Marilyn-Monroe
# /author/Albert-Einstein
# /author/Andre-Gide
# /author/Thomas-A-Edison
# /author/Eleanor-Roosevelt
# /author/Steve-Martin

# %%
sp.find_all('a',class_ = 'tag')
# Out:
# [<a class="tag" href="/tag/humor/page/1/">humor</a>,
#  <a class="tag" href="/tag/obvious/page/1/">obvious</a>,
#  <a class="tag" href="/tag/simile/page/1/">simile</a>]

# %%
for tag in sp.find_all('a',class_ = 'tag'):
    print(tag.text)
# Out:
# humor
# obvious
# simile

# %%
tags = []

for tag in sp.find_all('a',class_ = 'tag'):
    tags.append(tag.text)

# %%
tags
# Out:
# ['humor', 'obvious', 'simile']

# %%
','.join(tags)
# Out:
# 'humor,obvious,simile'

# %%
for sp in Soup.find_all('div',class_ = 'quote'):
    quote      = sp.find('span',class_ = 'text').text[1:-1]
    author     = sp.find('small').text
    author_id  = sp.find('a').get('href')
    tags       = ','.join(tags)
    print(quote, author_id,tags)
    print('-'*20)
# Out:
# The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking. /author/Albert-Einstein humor,obvious,simile
# --------------------
# It is our choices, Harry, that show what we truly are, far more than our abilities. /author/J-K-Rowling h,u,m,o,r,,,o,b,v,i,o,u,s,,,s,i,m,i,l,e
# --------------------
# There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle. /author/Albert-Einstein h,,,u,,,m,,,o,,,r,,,,,,,o,,,b,,,v,,,i,,,o,,,u,,,s,,,,,,,s,,,i,,,m,,,i,,,l,,,e
# --------------------
# The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid. /author/Jane-Austen h,,,,,,,u,,,,,,,m,,,,,,,o,,,,,,,r,,,,,,,,,,,,,,,o,,,,,,,b,,,,,,,v,,,,,,,i,,,,,,,o,,,,,,,u,,,,,,,s,,,,,,,,,,,,,,,s,,,,,,,i,,,,,,,m,,,,,,,i,,,,,,,l,,,,,,,e
# --------------------
# ...

# %%
for sp in Soup.find_all('div',class_ = 'quote'):
    quote      = sp.find('span',class_ = 'text').text[1:-1]
    author     = sp.find('small').text
    author_id  = sp.find('a').get('href')
    
    tags = []
    for tag in sp.find_all('a',class_ = 'tag'):
        tags.append(tag.text)
    tags       = ','.join(tags)
    print(quote)
    print(author_id)
    print(tags)
    print('-'*20)
# Out:
# The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.
# /author/Albert-Einstein
# change,deep-thoughts,thinking,world
# --------------------
# It is our choices, Harry, that show what we truly are, far more than our abilities.
# /author/J-K-Rowling
# abilities,choices
# --------------------
# There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.
# /author/Albert-Einstein
# inspirational,life,live,miracle,miracles
# --------------------
# The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.
# /author/Jane-Austen
# aliteracy,books,classic,humor
# --------------------
# Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.
# /author/Marilyn-Monroe
# be-yourself,inspirational
# --------------------
# ...

# %%
data = []

for sp in Soup.find_all('div',class_ = 'quote'):
    quote      = sp.find('span',class_ = 'text').text[1:-1]
    author     = sp.find('small').text
    author_id  = sp.find('a').get('href')
    
    tags = []
    for tag in sp.find_all('a',class_ = 'tag'):
        tags.append(tag.text)
    tags       = ','.join(tags)
    
    data.append([quote, author_id,tags])

# %%
len(data)
# Out:
# 10

# %%
#alternate code for above 
import pandas as pd

data = [
    ['The only way to do great work is to love what you do.', 'Steve Jobs', '100', 'inspiration,work'],
    ['Believe you can and you\'re halfway there.', 'Theodore Roosevelt', '200', 'motivation,believe'],
    ['Don\'t watch the clock; do what it does. Keep going.', 'Sam Levenson', '300', 'time,motivation'],
    ['The harder I practice, the luckier I get.', 'Gary Player', '400', 'golf,sports'],
    ['The greatest glory in living lies not in never falling, but in rising every time we fall.', 'Nelson Mandela', '500', 'motivation,resilience']
]

df = pd.DataFrame(data, columns=['quote', 'author', 'author_id', 'tags'])
print(df)
# Out:
#                                                quote              author  \
# 0  The only way to do great work is to love what ...          Steve Jobs
# 1          Believe you can and you're halfway there.  Theodore Roosevelt
# 2  Don't watch the clock; do what it does. Keep g...        Sam Levenson
# 3          The harder I practice, the luckier I get.         Gary Player
# 4  The greatest glory in living lies not in never...      Nelson Mandela
#
#   author_id                   tags
# 0       100       inspiration,work
# 1       200     motivation,believe
# 2       300        time,motivation
# 3       400            golf,sports
# 4       500  motivation,resilience

# %%
df = pd.DataFrame(data, columns=['quote', 'author', 'author_id', 'tags'])
print(df)
# Out:
#                                                 quote              author  \
# 0   The world as we have created it is a process o...     Albert Einstein
# 1   It is our choices, Harry, that show what we tr...        J.K. Rowling
# 2   There are only two ways to live your life. One...     Albert Einstein
# 3   The person, be it gentleman or lady, who has n...         Jane Austen
# 4   Imperfection is beauty, madness is genius and ...      Marilyn Monroe
# ..                                                ...                 ...
# 95  You never really understand a person until you...          Harper Lee
# 96  You have to write the book that wants to be wr...   Madeleine L'Engle
# 97  Never tell the truth to people who are not wor...          Mark Twain
# 98          A person's a person, no matter how small.           Dr. Seuss
# 99  ... a mind needs books as a sword needs a whet...  George R.R. Martin
#
#                     author_id  \
# 0     /author/Albert-Einstein
# ...

# %%
data
# Out:
# [['The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.',
#   '/author/Albert-Einstein',
#   'change,deep-thoughts,thinking,world'],
#  ['It is our choices, Harry, that show what we truly are, far more than our abilities.',
#   '/author/J-K-Rowling',
#   'abilities,choices'],
#  ['There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.',
#   '/author/Albert-Einstein',
#   'inspirational,life,live,miracle,miracles'],
#  ['The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.',
#   '/author/Jane-Austen',
#   'aliteracy,books,classic,humor'],
#  ["Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.",
#   '/author/Marilyn-Monroe',
#   'be-yourself,inspirational'],
#  ['Try not to become a man of success. Rather become a man of value.',
# ...

# %%
data[0]
# Out:
# ['The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.',
#  '/author/Albert-Einstein',
#  'change,deep-thoughts,thinking,world']

# %%
for page in range(2,11):
    print('https://quotes.toscrape.com/page/' + str(page))
# Out:
# https://quotes.toscrape.com/page/2
# https://quotes.toscrape.com/page/3
# https://quotes.toscrape.com/page/4
# https://quotes.toscrape.com/page/5
# https://quotes.toscrape.com/page/6
# https://quotes.toscrape.com/page/7
# https://quotes.toscrape.com/page/8
# https://quotes.toscrape.com/page/9
# https://quotes.toscrape.com/page/10

# %%
from tqdm import tqdm

# %%
data = []

for page in tqdm(range(1,11)):
    link = 'https://quotes.toscrape.com/page/' + str(page)
    res  = requests.get(link)
    soup = BeautifulSoup(res.text, 'html.parser')
    
    for sp in soup.find_all('div', class_ = 'quote'):

        quote     = sp.find('span', class_ = 'text').text[1:-1]
        author    = sp.find('small').text
        author_id = sp.find('a').get('href')

        tags = []
        for tag in sp.find_all('a',class_ = 'tag'):
            tags.append(tag.text)
        tags      = ','.join(tags)

        data.append([quote, author, author_id, tags])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:01<00:00,  6.20s/it]

# %%
data
# Out:
# [['The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.',
#   'Albert Einstein',
#   '/author/Albert-Einstein',
#   'change,deep-thoughts,thinking,world'],
#  ['It is our choices, Harry, that show what we truly are, far more than our abilities.',
#   'J.K. Rowling',
#   '/author/J-K-Rowling',
#   'abilities,choices'],
#  ['There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.',
#   'Albert Einstein',
#   '/author/Albert-Einstein',
#   'inspirational,life,live,miracle,miracles'],
#  ['The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.',
#   'Jane Austen',
#   '/author/Jane-Austen',
#   'aliteracy,books,classic,humor'],
#  ["Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.",
#   'Marilyn Monroe',
#   '/author/Marilyn-Monroe',
# ...

# %%
len(data)
# Out:
# 100

# %%
df = pd.DataFrame(data, columns = ['quote','author','author_id','tags'])

# %%
df
# Out:
#                                                 quote              author  \
# 0   The world as we have created it is a process o...     Albert Einstein
# 1   It is our choices, Harry, that show what we tr...        J.K. Rowling
# 2   There are only two ways to live your life. One...     Albert Einstein
# 3   The person, be it gentleman or lady, who has n...         Jane Austen
# 4   Imperfection is beauty, madness is genius and ...      Marilyn Monroe
# ..                                                ...                 ...
# 95  You never really understand a person until you...          Harper Lee
# 96  You have to write the book that wants to be wr...   Madeleine L'Engle
# 97  Never tell the truth to people who are not wor...          Mark Twain
# 98          A person's a person, no matter how small.           Dr. Seuss
# 99  ... a mind needs books as a sword needs a whet...  George R.R. Martin
#
#                     author_id  \
# 0     /author/Albert-Einstein
# ...

# %%
df['author_id']#this will give page link for all pages
# Out:
# 0       /author/Albert-Einstein
# 1           /author/J-K-Rowling
# 2       /author/Albert-Einstein
# 3           /author/Jane-Austen
# 4        /author/Marilyn-Monroe
#                 ...
# 95           /author/Harper-Lee
# 96     /author/Madeleine-LEngle
# 97           /author/Mark-Twain
# 98             /author/Dr-Seuss
# 99    /author/George-R-R-Martin
# Name: author_id, Length: 100, dtype: object

# %%
'https://quotes.toscrape.com' + df['author_id']
# Out:
# 0     https://quotes.toscrape.com/author/Albert-Eins...
# 1        https://quotes.toscrape.com/author/J-K-Rowling
# 2     https://quotes.toscrape.com/author/Albert-Eins...
# 3        https://quotes.toscrape.com/author/Jane-Austen
# 4     https://quotes.toscrape.com/author/Marilyn-Monroe
#                             ...
# 95        https://quotes.toscrape.com/author/Harper-Lee
# 96    https://quotes.toscrape.com/author/Madeleine-L...
# 97        https://quotes.toscrape.com/author/Mark-Twain
# 98          https://quotes.toscrape.com/author/Dr-Seuss
# 99    https://quotes.toscrape.com/author/George-R-R-...
# Name: author_id, Length: 100, dtype: object

# %%
df['author_link'] = 'https://quotes.toscrape.com' + df['author_id']

# %%
df
# Out:
#                                                 quote              author  \
# 0   The world as we have created it is a process o...     Albert Einstein
# 1   It is our choices, Harry, that show what we tr...        J.K. Rowling
# 2   There are only two ways to live your life. One...     Albert Einstein
# 3   The person, be it gentleman or lady, who has n...         Jane Austen
# 4   Imperfection is beauty, madness is genius and ...      Marilyn Monroe
# ..                                                ...                 ...
# 95  You never really understand a person until you...          Harper Lee
# 96  You have to write the book that wants to be wr...   Madeleine L'Engle
# 97  Never tell the truth to people who are not wor...          Mark Twain
# 98          A person's a person, no matter how small.           Dr. Seuss
# 99  ... a mind needs books as a sword needs a whet...  George R.R. Martin
#
#                     author_id  \
# 0     /author/Albert-Einstein
# ...

# %%
df.to_csv('Quotes.csv', index = False)

# %%
df
# Out:
#                                                 quote              author  \
# 0   The world as we have created it is a process o...     Albert Einstein
# 1   It is our choices, Harry, that show what we tr...        J.K. Rowling
# 2   There are only two ways to live your life. One...     Albert Einstein
# 3   The person, be it gentleman or lady, who has n...         Jane Austen
# 4   Imperfection is beauty, madness is genius and ...      Marilyn Monroe
# ..                                                ...                 ...
# 95  You never really understand a person until you...          Harper Lee
# 96  You have to write the book that wants to be wr...   Madeleine L'Engle
# 97  Never tell the truth to people who are not wor...          Mark Twain
# 98          A person's a person, no matter how small.           Dr. Seuss
# 99  ... a mind needs books as a sword needs a whet...  George R.R. Martin
#
#                     author_id  \
# 0     /author/Albert-Einstein
# ...

# %% [markdown]
# # Book scraper

# %%
link = 'https://books.toscrape.com/catalogue/page-1.html'

# %%
res = requests.get(link)

soup = BeautifulSoup(res.text, 'html.parser')

# %%
soup.find_all('li', class_= 'col-xs-6 col-sm-4 col-md-3 col-lg-3')
# Out:
# [<li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
#  <article class="product_pod">
#  <div class="image_container">
#  <a href="a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="../media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
#  </div>
#  <p class="star-rating Three">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>
#  <h3><a href="a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
#  <div class="product_price">
#  <p class="price_color">Â£51.77</p>
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>
#  <form>
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
#  </form>
#  </div>
#  </article>
#  </li>,
#  <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
# ...

# %%
for sp in soup.find_all('li', class_= 'col-xs-6 col-sm-4 col-md-3 col-lg-3'):
    print(sp)
    break
# Out:
# <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
# <article class="product_pod">
# <div class="image_container">
# <a href="a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="../media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
# </div>
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
# <div class="product_price">
# <p class="price_color">Â£51.77</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>
# </li>

# %%
data = []

for sp in soup.find_all('li', class_= 'col-xs-6 col-sm-4 col-md-3 col-lg-3'):
        
    img_link   = 'https://books.toscrape.com/' + sp.find('img').get('src')[3:]
    book_link  = 'https://books.toscrape.com/catalogue/' + sp.find_all('a')[-1].get('href')
    title      = sp.find_all('a')[-1].get('title')
    rating     = sp.find('p').get('class')[-1]
    price      = sp.find('p',class_ = 'price_color').text[2:]
    stock      = sp.find('p', class_ = 'instock availability').text.strip()
    
    
    data.append([title, rating, price, stock, book_link, img_link])

# %%
data
# Out:
# [['A Light in the Attic',
#   'Three',
#   '51.77',
#   'In stock',
#   'https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html',
#   'https://books.toscrape.com/media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg'],
#  ['Tipping the Velvet',
#   'One',
#   '53.74',
#   'In stock',
#   'https://books.toscrape.com/catalogue/tipping-the-velvet_999/index.html',
#   'https://books.toscrape.com/media/cache/26/0c/260c6ae16bce31c8f8c95daddd9f4a1c.jpg'],
#  ['Soumission',
#   'One',
#   '50.10',
#   'In stock',
#   'https://books.toscrape.com/catalogue/soumission_998/index.html',
#   'https://books.toscrape.com/media/cache/3e/ef/3eef99c9d9adef34639f510662022830.jpg'],
#  ['Sharp Objects',
#   'Four',
#   '47.82',
#   'In stock',
#   'https://books.toscrape.com/catalogue/sharp-objects_997/index.html',
#   'https://books.toscrape.com/media/cache/32/51/3251cf3a3412f53f339e42cac2134093.jpg'],
#  ['Sapiens: A Brief History of Humankind',
#   'Five',
#   '54.23',
# ...

# %%
len(data)
# Out:
# 20

# %%
data[0]
# Out:
# ['A Light in the Attic',
#  'Three',
#  '51.77',
#  'In stock',
#  'https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html',
#  'https://books.toscrape.com/media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg']

# %%
df = pd.DataFrame(data, columns = ['title', 'rating', 'price', 'stock', 'book_link','img_link'])

# %%
df.head()
# Out:
#                                    title rating  price     stock  \
# 0                   A Light in the Attic  Three  51.77  In stock
# 1                     Tipping the Velvet    One  53.74  In stock
# 2                             Soumission    One  50.10  In stock
# 3                          Sharp Objects   Four  47.82  In stock
# 4  Sapiens: A Brief History of Humankind   Five  54.23  In stock
#
#                                            book_link  \
# 0  https://books.toscrape.com/catalogue/a-light-i...
# 1  https://books.toscrape.com/catalogue/tipping-t...
# 2  https://books.toscrape.com/catalogue/soumissio...
# 3  https://books.toscrape.com/catalogue/sharp-obj...
# 4  https://books.toscrape.com/catalogue/sapiens-a...
#
#                                             img_link
# 0  https://books.toscrape.com/media/cache/2c/da/2...
# 1  https://books.toscrape.com/media/cache/26/0c/2...
# 2  https://books.toscrape.com/media/cache/3e/ef/3...
# ...

# %%
df.to_csv('books.csv', index = False)

# %% [markdown]
# # Book scraper(individual page)

# %%
df = pd.read_csv('books.csv')
df.head()
# Out:
#                                    title rating  price     stock  \
# 0                   A Light in the Attic  Three  51.77  In stock
# 1                     Tipping the Velvet    One  53.74  In stock
# 2                             Soumission    One  50.10  In stock
# 3                          Sharp Objects   Four  47.82  In stock
# 4  Sapiens: A Brief History of Humankind   Five  54.23  In stock
#
#                                            book_link  \
# 0  https://books.toscrape.com/catalogue/a-light-i...
# 1  https://books.toscrape.com/catalogue/tipping-t...
# 2  https://books.toscrape.com/catalogue/soumissio...
# 3  https://books.toscrape.com/catalogue/sharp-obj...
# 4  https://books.toscrape.com/catalogue/sapiens-a...
#
#                                             img_link
# 0  https://books.toscrape.com/media/cache/2c/da/2...
# 1  https://books.toscrape.com/media/cache/26/0c/2...
# 2  https://books.toscrape.com/media/cache/3e/ef/3...
# ...

# %%
for link in df['book_link']:
    res = requests.get(link)
    soup = BeautifulSoup(res.text,'html.parser')
    print(soup.text)
    break
# Out:
#
#
#
#     A Light in the Attic | Books to Scrape - Sandbox
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Books to Scrape We love being scraped!
#
#
#
#
#
#
#
#
# Home
#
#
# Books
#
#
# Poetry
#
# A Light in the Attic
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# A Light in the Attic
# Â£51.77
#
#
#
#         In stock (22 available)
#
#
#
#
#
#
#
#
#
#
#
#
#
# Warning! This is a demo website for web scraping purposes. Prices and ratings here were randomly assigned and have no real meaning.
#
#
#
# Product Description
#
# ...

# %%
for link in tqdm(df['book_link']):
    
    res = requests.get(link)
    soup = BeautifulSoup(res.text, 'html.parser')
    
    print(soup.find('ul', class_ = 'breadcrumb').find_all('a')[2].text)
    break
# Out:
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
# Poetry

# %%
for link in df['book_link']:
    
    res     = requests.get(link)
    soup    = BeautifulSoup(res.text, 'html.parser')
    
    typ = soup.find('ul', class_ = 'breadcrumb').find_all('a')[2].text
    
    upc     = soup.find('table', class_ = 'table table-striped').find_all('td')[0].text
    price_x = soup.find('table', class_ = 'table table-striped').find_all('td')[2].text[2:]
    price_i = soup.find('table', class_ = 'table table-striped').find_all('td')[3].text[2:]
    tax     = soup.find('table', class_ = 'table table-striped').find_all('td')[4].text[2:]
    qn      = soup.find('table', class_ = 'table table-striped').find_all('td')[5].text
    reviews    = soup.find('table', class_ = 'table table-striped').find_all('td')[6].text

    break

# %%
typ
# Out:
# 'Poetry'

# %%
upc
# Out:
# 'a897fe39b1053632'

# %%
price_x
# Out:
# '51.77'

# %%
price_i
# Out:
# '51.77'

# %%
tax
# Out:
# '0.00'

# %%
qn
# Out:
# 'In stock (22 available)'

# %%
reviews
# Out:
# '0'

# %%
data = []

for link in df['book_link']:
    
    res     = requests.get(link)
    soup    = BeautifulSoup(res.text, 'html.parser')
    
    typ = soup.find('ul', class_ = 'breadcrumb').find_all('a')[2].text
    
    upc     = soup.find('table', class_ = 'table table-striped').find_all('td')[0].text
    price_x = soup.find('table', class_ = 'table table-striped').find_all('td')[2].text[2:]
    price_i = soup.find('table', class_ = 'table table-striped').find_all('td')[3].text[2:]
    tax     = soup.find('table', class_ = 'table table-striped').find_all('td')[4].text[2:]
    qn      = soup.find('table', class_ = 'table table-striped').find_all('td')[5].text
    reviews = soup.find('table', class_ = 'table table-striped').find_all('td')[6].text
   
    data.append([typ, price_x, price_i, tax, qn, upc, reviews])

# %%
data
# Out:
# [['Poetry',
#   '51.77',
#   '51.77',
#   '0.00',
#   'In stock (22 available)',
#   'a897fe39b1053632',
#   '0'],
#  ['Historical Fiction',
#   '53.74',
#   '53.74',
#   '0.00',
#   'In stock (20 available)',
#   '90fa61229261140a',
#   '0'],
#  ['Fiction',
#   '50.10',
#   '50.10',
#   '0.00',
#   'In stock (20 available)',
#   '6957f44c3847a760',
#   '0'],
#  ['Mystery',
#   '47.82',
#   '47.82',
#   '0.00',
#   'In stock (20 available)',
#   'e00eb4fd7b871a48',
#   '0'],
#  ['History',
#   '54.23',
#   '54.23',
#   '0.00',
#   'In stock (20 available)',
#   '4165285e1663650f',
#   '0'],
#  ['Young Adult',
#   '22.65',
#   '22.65',
#   '0.00',
#   'In stock (19 available)',
#   'f77dbf2323deb740',
#   '0'],
#  ['Business',
#   '33.34',
#   '33.34',
#   '0.00',
#   'In stock (19 available)',
#   '2597b5a345f45e1b',
#   '0'],
#  ['Default',
#   '17.93',
#   '17.93',
#   '0.00',
#   'In stock (19 available)',
#   'e72a5dfc7e9267b2',
#   '0'],
#  ['Default',
#   '22.60',
#   '22.60',
# ...

# %%
import requests
import pandas as pd
from tqdm import tqdm
from bs4 import BeautifulSoup

df = pd.read_csv('Quotes.csv')
df.head()
# Out:
#                                                quote           author  \
# 0  The world as we have created it is a process o...  Albert Einstein
# 1  It is our choices, Harry, that show what we tr...     J.K. Rowling
# 2  There are only two ways to live your life. One...  Albert Einstein
# 3  The person, be it gentleman or lady, who has n...      Jane Austen
# 4  Imperfection is beauty, madness is genius and ...   Marilyn Monroe
#
#                  author_id                                      tags  \
# 0  /author/Albert-Einstein       change,deep-thoughts,thinking,world
# 1      /author/J-K-Rowling                         abilities,choices
# 2  /author/Albert-Einstein  inspirational,life,live,miracle,miracles
# 3      /author/Jane-Austen             aliteracy,books,classic,humor
# 4   /author/Marilyn-Monroe                 be-yourself,inspirational
#
#                                          author_link
# 0  https://quotes.toscrape.com/author/Albert-Eins...
# ...

# %% [markdown]
# ##approch-2

# %%
data = []

for link in tqdm(df['book_link']):
    
    res = requests.get(link)
    soup = BeautifulSoup(res.text, 'html.parser')
    
    typ = soup.find('ul', class_ = 'breadcrumb').find_all('a')[2].text
    
    temp = soup.find('table', class_ = 'table table-striped').find_all('td')
    
    upc      = temp[0].text
    price_x  = temp[2].text[2:]
    price_i  = temp[3].text[2:]
    tax      = temp[4].text[2:]
    qn       = temp[5].text
    reviews  = temp[6].text
    
    data.append([typ, price_x, price_i, tax, qn, upc, reviews])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:25<00:00,  1.28s/it]

# %%
df = pd.DataFrame(data, columns = ['Category','price_ex_tax','price_in_tax','tax','quanity','upc','reviews'])
df.head()
# Out:
#              Category price_ex_tax price_in_tax   tax  \
# 0              Poetry        51.77        51.77  0.00
# 1  Historical Fiction        53.74        53.74  0.00
# 2             Fiction        50.10        50.10  0.00
# 3             Mystery        47.82        47.82  0.00
# 4             History        54.23        54.23  0.00
#
#                    quanity               upc reviews
# 0  In stock (22 available)  a897fe39b1053632       0
# 1  In stock (20 available)  90fa61229261140a       0
# 2  In stock (20 available)  6957f44c3847a760       0
# 3  In stock (20 available)  e00eb4fd7b871a48       0
# 4  In stock (20 available)  4165285e1663650f       0

# %%
df.isnull()
# Out:
#     Category  price_ex_tax  price_in_tax    tax  quanity    upc  reviews
# 0      False         False         False  False    False  False    False
# 1      False         False         False  False    False  False    False
# 2      False         False         False  False    False  False    False
# 3      False         False         False  False    False  False    False
# 4      False         False         False  False    False  False    False
# 5      False         False         False  False    False  False    False
# 6      False         False         False  False    False  False    False
# 7      False         False         False  False    False  False    False
# 8      False         False         False  False    False  False    False
# 9      False         False         False  False    False  False    False
# 10     False         False         False  False    False  False    False
# 11     False         False         False  False    False  False    False
# ...

# %%
df.to_csv('data.csv', index = False)

# %% [markdown]
# ###Add two csv files

# %%
df_1 = pd.read_csv('books.csv')
df_2 = pd.read_csv('data.csv')

# %%
df_1.head()
# Out:
#                                    title rating  price     stock  \
# 0                   A Light in the Attic  Three  51.77  In stock
# 1                     Tipping the Velvet    One  53.74  In stock
# 2                             Soumission    One  50.10  In stock
# 3                          Sharp Objects   Four  47.82  In stock
# 4  Sapiens: A Brief History of Humankind   Five  54.23  In stock
#
#                                            book_link  \
# 0  https://books.toscrape.com/catalogue/a-light-i...
# 1  https://books.toscrape.com/catalogue/tipping-t...
# 2  https://books.toscrape.com/catalogue/soumissio...
# 3  https://books.toscrape.com/catalogue/sharp-obj...
# 4  https://books.toscrape.com/catalogue/sapiens-a...
#
#                                             img_link
# 0  https://books.toscrape.com/media/cache/2c/da/2...
# 1  https://books.toscrape.com/media/cache/26/0c/2...
# 2  https://books.toscrape.com/media/cache/3e/ef/3...
# ...

# %%
df_2.head()
# Out:
#              Category  price_ex_tax  price_in_tax  tax  \
# 0              Poetry         51.77         51.77  0.0
# 1  Historical Fiction         53.74         53.74  0.0
# 2             Fiction         50.10         50.10  0.0
# 3             Mystery         47.82         47.82  0.0
# 4             History         54.23         54.23  0.0
#
#                    quanity               upc  reviews
# 0  In stock (22 available)  a897fe39b1053632        0
# 1  In stock (20 available)  90fa61229261140a        0
# 2  In stock (20 available)  6957f44c3847a760        0
# 3  In stock (20 available)  e00eb4fd7b871a48        0
# 4  In stock (20 available)  4165285e1663650f        0

# %% [markdown]
# # creating a empty Data frame

# %%
#here we make another table which have content of both tables
df = pd.DataFrame()

df['title']         = df_1['title']
df['upc']           = df_2['upc']

# %%
df.head()
# Out:
#                                    title               upc
# 0                   A Light in the Attic  a897fe39b1053632
# 1                     Tipping the Velvet  90fa61229261140a
# 2                             Soumission  6957f44c3847a760
# 3                          Sharp Objects  e00eb4fd7b871a48
# 4  Sapiens: A Brief History of Humankind  4165285e1663650f

# %%
df = pd.DataFrame()

df['title']         = df_1['title']
df['upc']           = df_2['upc']
df['Category']      = df_2['Category']

# %%
df.head()
# Out:
#                                    title               upc            Category
# 0                   A Light in the Attic  a897fe39b1053632              Poetry
# 1                     Tipping the Velvet  90fa61229261140a  Historical Fiction
# 2                             Soumission  6957f44c3847a760             Fiction
# 3                          Sharp Objects  e00eb4fd7b871a48             Mystery
# 4  Sapiens: A Brief History of Humankind  4165285e1663650f             History

# %%
df = pd.DataFrame()

df['title']         = df_1['title']
df['upc']           = df_2['upc']
df['Category']      = df_2['Category']
df['price_ex_tax']  = df_2['price_ex_tax']
df['price_in_tax']  = df_2['price_in_tax']
df['tax']           = df_2['tax']
df['rating']        = df_1['rating']
df['reviews']       = df_2['reviews']
df['quanity']       = df_2['quanity']
df['stock']         = df_1['stock']

df['book_link']     = df_1['book_link']
df['img_link']      = df_1['img_link']

# %%
df.head()
# Out:
#                                    title               upc  \
# 0                   A Light in the Attic  a897fe39b1053632
# 1                     Tipping the Velvet  90fa61229261140a
# 2                             Soumission  6957f44c3847a760
# 3                          Sharp Objects  e00eb4fd7b871a48
# 4  Sapiens: A Brief History of Humankind  4165285e1663650f
#
#              Category  price_ex_tax  price_in_tax  tax rating  reviews  \
# 0              Poetry         51.77         51.77  0.0  Three        0
# 1  Historical Fiction         53.74         53.74  0.0    One        0
# 2             Fiction         50.10         50.10  0.0    One        0
# 3             Mystery         47.82         47.82  0.0   Four        0
# 4             History         54.23         54.23  0.0   Five        0
#
#                    quanity     stock  \
# 0  In stock (22 available)  In stock
# 1  In stock (20 available)  In stock
# 2  In stock (20 available)  In stock
# ...

# %%
df.isnull().sum()
# Out:
# title           0
# upc             0
# Category        0
# price_ex_tax    0
# price_in_tax    0
# tax             0
# rating          0
# reviews         0
# quanity         0
# stock           0
# book_link       0
# img_link        0
# dtype: int64

# %%
df.to_csv('final.csv',index = False)

# %%
df.to_csv('final1.csv', index = False)
